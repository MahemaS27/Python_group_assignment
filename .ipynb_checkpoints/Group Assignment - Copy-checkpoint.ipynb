# %% [markdown]
# # Group Assignment

# %% [markdown]
# ### Import the necessary libraries

# %%
import numpy as np
import pandas as pd

import datetime as dt
import pandas_datareader.data as web

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from scipy.optimize import minimize
from scipy import stats

import statsmodels.api as sm

# %% [markdown]
# ## PART I

# %% [markdown]
# ## Examination of the January Effect
# ### The January Effect's main hypothesis states that stock returns are, on average, higher during January than during other months.

# %% [markdown]
# ### 1. Download pricing data from Yahoo!Finance for each of the stocks in the ticker_list below and compute the continuously compounded daily returns using the Adjusted Closing price. Store these daily returns in a DataFrame called returns. Label the columns as 'RET_ticker', where ticker represents the trading symbol of the stock whose returns are stored in that column.

# %%
ticker_list = ['AAPL', 'AXP', 'BA', 'CAT', 'CSCO', 'CVX', 'DIS', 'GS', 'HD', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO',
            'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PFE', 'PG', 'TRV', 'UNH', 'UTX', 'V', 'VZ', 'WMT', 'XOM']

# %%
start = dt.datetime(2013,1,1)
end = dt.datetime(2019, 12,31)
yahoo = web.DataReader(ticker_list, 'yahoo', start,end)

# %%
yahoo.head()
# Out:
# Attributes  Adj Close                                                         \
# Symbols          AAPL        AXP         BA        CAT       CSCO        CVX
# Date
# 2013-01-02  68.687538  52.794613  64.088791  74.283417  16.198055  83.131775
# 2013-01-03  67.820526  53.019272  64.421425  74.998421  16.285658  82.777863
# 2013-01-04  65.931404  53.567421  64.604370  75.411537  16.309542  83.214630
# 2013-01-07  65.543602  53.792095  63.307129  75.641953  16.158239  82.649834
# 2013-01-08  65.719994  54.097630  61.643993  74.680672  16.174168  82.280815
#
# Attributes                                                ...     Volume  \
# Symbols           DIS          GS         HD         IBM  ...        NKE
# Date                                                      ...
# 2013-01-02  46.454643  118.254135  54.007660  149.965622  ...  7512800.0
# 2013-01-03  46.554642  117.607460  53.854519  149.140732  ...  7232200.0
# 2013-01-04  47.445557  120.813934  53.752422  148.163147  ...  6794000.0
# 2013-01-07  46.336468  120.589355  53.463146  147.513916  ...  6489400.0
# 2013-01-08  46.145550  119.502602  53.786449  147.307709  ...  6714200.0
#
# Attributes                                                           \
# Symbols            PFE         PG        TRV         UNH        UTX
# Date
# 2013-01-02  33522200.0  9987000.0  2886500.0   5358100.0  4485200.0
# 2013-01-03  33757400.0  7741900.0  2124800.0  14413200.0  3786600.0
# 2013-01-04  28604900.0  5853700.0  2013300.0  10458000.0  3855900.0
# 2013-01-07  25779900.0  5269800.0  2207500.0   7804500.0  3378500.0
# 2013-01-08  31057000.0  7362000.0  1431200.0   8196200.0  4830600.0
#
# Attributes
# Symbols              V          VZ         WMT         XOM
# Date
# 2013-01-02  15826400.0  16483900.0  10390800.0  16143700.0
# 2013-01-03  14937200.0  11227700.0   8910100.0  13268200.0
# 2013-01-04  10376000.0  14930400.0   6438000.0  11427900.0
# 2013-01-07  10242400.0  20891300.0   6201400.0  11799800.0
# 2013-01-08  11800400.0  21394400.0   5866900.0  14226400.0
#
# [5 rows x 168 columns]

# %%
adj_close = yahoo['Adj Close']
tickers = adj_close.columns

# %%
returns = pd.DataFrame() 
for ticker in tickers:
    returns['RET_'+ticker] = np.log(adj_close[ticker]/adj_close[ticker].shift(1))
    
returns.head() # return for each ticker
# Out:
#             RET_AAPL   RET_AXP    RET_BA   RET_CAT  RET_CSCO   RET_CVX  \
# Date
# 2013-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2013-01-
# 2018-03-30  0.001674 -0.005677 -0.015032
# 2018-04-30  0.043998 -0.005749  0.041224
# 2018-05-31 -0.034636 -0.062987  0.053994
# 2018-06-29  0.053902  0.036986  0.018175
# 2018-07-31  0.037619  0.040948 -0.014857
# 2018-08-31  0.051516  0.077463 -0.006315
# 2018-09-28 -0.018189 -0.020552  0.058737
# 2018-10-31  0.078017  0.065629 -0.064868
# 2018-11-30  0.054703 -0.026577  0.007825
# 2018-12-31 -0.070060 -0.041736 -0.153459
# 2019-01-31 -0.010475  0.028365  0.071990
# 2019-02-28  0.033223  0.032443  0.086581
# 2019-03-29  0.038092 -0.009493  0.022149
# 2019-04-30 -0.023118  0.053014 -0.006456
# 2019-05-31 -0.050934 -0.008409 -0.114688
# 2019-06-28  0.049885  0.085457  0.079554
# 2019-07-31 -0.022637 -0.000996 -0.030071
# 2019-08-30  0.050968  0.039458 -0.070019
# 2019-09-30  0.037129  0.037954  0.030630
# 2019-10-31  0.012172 -0.012037 -0.044008
# 2019-11-29 -0.003811  0.015486  0.020241
# 2019-12-31  0.019073  0.002374  0.023930
#
# [84 rows x 28 columns]

# %% [markdown]
# ### 3. Create a dummy variable (labeled "JAN_DUMMY") in the DataFrame returns_mon, and assign it a value of 1 if the month is January, and 0 otherwise.

# %%
returns_mon.loc[returns_mon.index.month == 1, 'JAN_DUMMY'] = 1
returns_mon.loc[returns_mon.index.month != 1, 'JAN_DUMMY'] = 0

returns_mon.head(12)
# Out:
#             RET_AAPL   RET_AXP    RET_BA   RET_CAT  RET_CSCO   RET_CVX  \
# Date
# 2013-01-31 -0.186780  0.001021 -0.042407  0.050977  0.011244  0.042217
# 2013-02-28 -0.025611  0.055239  0.046602 -0.063137  0.014000  0.024975
# 2013-03-29  0.002850  0.081984  0.110095 -0.060239  0.001915  0.014155
# 2013-04-30  0.000271  0.016945  0.062754 -0.020399  0.009008  0.026493
# 2013-05-31  0.022172  0.101391  0.085096  0.013258  0.142336  0.014079
# 2013-06-28 -0.125896 -0.012627  0.033956 -0.039342  0.009080 -0.036588
# 2013-07-31  0.132102 -0.010286  0.025635  0.012026  0.057090  0.061847
# 2013-08-30  0.080443 -0.025537 -0.006750 -0.004472 -0.093319 -0.036112
# 2013-09-30 -0.021724  0.048982  0.122817  0.010365  0.005135  0.008845
# 2013-10-31  0.092016  0.082914  0.104935  0.006499 -0.030557 -0.012756
# 2013-11-29  0.067708  0.047742  0.031968  0.014766 -0.059821  0.028825
# 2013-12-31  0.008863  0.055869  0.016548  0.070835  0.054043  0.019972
#
#              RET_DIS    RET_GS    RET_HD   RET_IBM  ...   RET_PFE    RET_PG  \
# Date                                                ...
# 2013-01-31  0.052975  0.116043  0.052773  0.033652  ...  0.060227  0.087951
# 2013-02-28  0.013091  0.016160  0.023336 -0.006892  ...  0.003294  0.013480
# 2013-03-29  0.039686 -0.017582  0.023997  0.060241  ...  0.053009  0.011485
# 2013-04-30  0.101056 -0.007366  0.049895 -0.051762  ...  0.007251  0.003544
# 2013-05-31  0.003812  0.107159  0.069892  0.031373  ... -0.057086 -0.000131
# 2013-06-28  0.001109 -0.069156 -0.010300 -0.084785  ...  0.028242  0.002992
# 2013-07-31  0.023475  0.081115  0.019937  0.020355  ...  0.050756  0.049551
# 2013-08-30 -0.060905 -0.072046 -0.059162 -0.062729  ... -0.035519 -0.030472
# 2013-09-30  0.058427  0.039188  0.023342  0.015839  ...  0.018265 -0.029974
# 2013-10-31  0.061637  0.016611  0.026540 -0.032770  ...  0.065995  0.073815
# 2013-11-29  0.028033  0.052288  0.035069  0.007975  ...  0.041038  0.042075
# 2013-12-31  0.092073  0.048074  0.025392  0.042975  ... -0.035283 -0.033935
#
#              RET_TRV   RET_UNH   RET_UTX     RET_V    RET_VZ   RET_WMT  \
# Date
# 2013-01-31  0.074049  0.012210  0.041622  0.016151 -0.003430  0.010202
# 2013-02-28  0.024674 -0.032398  0.039427  0.013066  0.064810  0.011795
# 2013-03-29  0.051476  0.071865  0.031310  0.068219  0.054780  0.062074
# 2013-04-30  0.014387  0.046449 -0.023171 -0.008158  0.102885  0.037893
# 2013-05-31 -0.019985  0.044067  0.044375  0.063219 -0.106165 -0.031780
# 2013-06-28 -0.040354  0.053286 -0.020870  0.025549  0.037649 -0.004688
# 2013-07-31  0.044419  0.106657  0.127420 -0.031913 -0.007142  0.045275
# 2013-08-30 -0.044669 -0.015354 -0.048182 -0.007348 -0.043368 -0.059700
# 2013-09-30  0.065384  0.001945  0.074294  0.091331 -0.015099  0.013339
# 2013-10-31  0.017888 -0.047911 -0.014669  0.028730  0.090341  0.037029
# 2013-11-29  0.050169  0.087207  0.047979  0.042045 -0.017777  0.054019
# 2013-12-31  0.003497  0.014754  0.026174  0.090266 -0.009721 -0.023252
#
#              RET_XOM  JAN_DUMMY
# Date
# 2013-01-31  0.014104        1.0
# 2013-02-28  0.001689        0.0
# 2013-03-29  0.006234        0.0
# 2013-04-30 -0.012507        0.0
# 2013-05-31  0.023388        0.0
# 2013-06-28 -0.001328        0.0
# 2013-07-31  0.036941        0.0
# 2013-08-30 -0.065998        0.0
# 2013-09-30 -0.012933        0.0
# 2013-10-31  0.040766        0.0
# 2013-11-29  0.048950        0.0
# 2013-12-31  0.079351        0.0
#
# [12 rows x 29 columns]

# %%
returns_mon['JAN_DUMMY'].value_counts()
# Out:
# 0.0    77
# 1.0     7
# Name: JAN_DUMMY, dtype: int64

# %% [markdown]
# ### 4. Use the DataFrame returns_mon to compute the average returns in January, and during non-January months for each year and for each stock, and store them in a new DataFrame named returns_jan_mon.

# %%
returns_jan_mon = returns_mon.groupby(["JAN_DUMMY", returns_mon.index.year]).mean()

# %%
returns_jan_mon
# Out:
#                 RET_AAPL   RET_AXP    RET_BA   RET_CAT  RET_CSCO   RET_CVX  \
# JAN_DUMMY Date
# 0.0       2013  0.021199  0.040238  0.057605 -0.005440  0.009901  0.010339
#           2014  0.041351  0.008945  0.005460 -0.000537  0.023865  0.003632
#           2015 -0.008201 -0.012520  0.001791 -0.012198  0.004805 -0.007858
#           2016  0.017803  0.030939  0.027287  0.038807  0.024149  0.031991
#           2017  0.031685  0.024931  0.056168  0.047322  0.022465  0.014192
#           2018 -0.004065 -0.002816 -0.006800 -0.020925  0.005882 -0.009440
#           2019  0.052970  0.018444 -0.013265  0.011367  0.003111  0.008152
# 1.0       2013 -0.186780  0.001021 -0.042407  0.050977  0.011244  0.042217
#           2015 -0.011378 -0.010535 -0.055944
#           2016  0.090235  0.079315 -0.001284
#           2017 -0.074787 -0.035040 -0.073188
#           2018  0.032635  0.076492  0.042829
#           2019 -0.010475  0.028365  0.071990
#
# [14 rows x 28 columns]

# %% [markdown]
# ### 5. a. Use the DataFrame returns_mon_jan to test, for each stock, whether the average return in January is higher than the average return on non-January months. Store the t-tests and p-values in a Dataframe called results_stock, along with the average returns in January, and during non-January months for each stock. The heading for the DataFrame is found below:

# %%
results_stock = pd.DataFrame(
{'Ticker':[], 
 'Jan_Avg':[], 
 'NonJan_Avg':[], 
 'T_Test':[], 
 'P_Value':[]}
)

for col in returns_jan_mon.columns: # for each stock
    ttest = stats.ttest_rel(returns_jan_mon[col].xs(1, level=0), returns_jan_mon[col].xs(0, level=0))
    
    results_stock = pd.concat([results_stock,
        pd.DataFrame(   {'Ticker':[col], 
                         'Jan_Avg': returns_jan_mon[col].xs(1, level=0).mean(), 
                         'NonJan_Avg':returns_jan_mon[col].xs(0, level=0).mean(), 
                         'T_Test':[ttest[0]], 
                         'P_Value':[ttest[1]/2]})], axis=0)
    
results_stock.set_index('Ticker', inplace=True)
results_stock.sort_index(inplace=True)

# %%
results_stock
# Out:
#            Jan_Avg  NonJan_Avg    T_Test   P_Value
# Ticker
# RET_AAPL -0.032815    0.021820 -1.438745  0.100137
# RET_AXP  -0.048709    0.015452 -1.459253  0.097391
# RET_BA    0.029893    0.018321  0.194975  0.425924
# RET_CAT   0.005401    0.008342 -0.103476  0.460478
# RET_CSCO  0.004681    0.013454 -0.280163  0.394381
# RET_CVX  -0.028775    0.007287 -1.503353  0.091720
# RET_DIS  -0.005363    0.015237 -0.951399  0.189068
# RET_GS   -0.001484    0.008691 -0.220600  0.416359
# RET_HD    0.011166    0.017043 -0.256237  0.403163
# RET_IBM   0.016165   -0.003062  0.514109  0.312777
# RET_INTC -0.029985    0.018820 -2.184030  0.035831
# RET_JNJ  -0.002314    0.012118 -1.208685  0.136126
# RET_JPM  -0.013046    0.018369 -0.897956  0.201900
# RET_KO   -0.009774    0.008778 -1.172385  0.142740
# RET_MCD   0.009572    0.012096 -0.181782  0.430870
# RET_MMM   0.007176    0.009770 -0.101798  0.461117
# RET_MRK   0.028135    0.010522  0.925985  0.195090
# RET_MSFT  0.004431    0.024361 -0.662293  0.266191
# RET_NKE   0.020283    0.017414  0.109574  0.458160
# RET_PFE  -0.003044    0.008862 -0.887690  0.204440
# RET_PG    0.007403    0.009809 -0.101847  0.461098
# RET_TRV  -0.001022    0.010381 -0.348870  0.369552
# RET_UNH   0.023598    0.021228  0.109540  0.458173
# RET_UTX   0.018972    0.007881  0.421019  0.344203
# RET_V     0.011676    0.020756 -0.494983  0.319107
# RET_VZ    0.001508    0.008190 -0.348222  0.369783
# RET_WMT   0.013785    0.008023  0.247375  0.406433
# RET_XOM  -0.013581    0.001339 -0.608571  0.282560

# %% [markdown]
# ### 5. b. Use the DataFrame results_stock to output the stocks for which the January effect hypothesis is true with a 95% degree of confidence. What about the observations where the hypothesis is true with 90% degree of confidence.

# %%
# pvalue that is less than or equal .05 and t greater than 0 
results_stock[(results_stock['T_Test']>0) & (results_stock['P_Value']<=.05)]
# Out:
# Empty DataFrame
# Columns: [Jan_Avg, NonJan_Avg, T_Test, P_Value]
# Index: []

# %%
# 90 confidence
results_stock[(results_stock['T_Test']>0) & (results_stock['P_Value']<=.10)]
# Out:
# Empty DataFrame
# Columns: [Jan_Avg, NonJan_Avg, T_Test, P_Value]
# Index: []

# %% [markdown]
# ### 6. a. Use the DataFrame returns_mon_jan to test, for each year, whether the average return in January is different from the average return on non-January months. Store the t-tests and p-values in a Dataframe called results_year, along with the average returns in January, and during non-January months for each year. The heading for the DataFrame is found below:

# %%
# all years
results_year = pd.DataFrame({'Year':[],
                             'Jan_Avg':[],
                             'NonJan_Avg':[],
                             'T_Test':[],
                             'P_Value':[]})
for year in returns_jan_mon.index.get_level_values('Date').unique():
    ttest=stats.ttest_rel(returns_jan_mon.xs(year,level=1).loc[1],
                          returns_jan_mon.xs(year,level=1).loc[0],
                           nan_policy='omit')
    results_year = pd.concat([results_year,
                         pd.DataFrame({
                        'Year':[year],
                        'Jan_Avg':returns_jan_mon.xs(year,level=1).loc[1].mean(),
                        'NonJan_Avg':returns_jan_mon.xs(year,level=1).loc[0].mean(),
                        'T_Test':ttest[0],
                        'P_Value':ttest[1]/2})],
                        axis = 0)
results_year.set_index('Year', inplace = True)
results_year.sort_index(inplace=True)
results_year.index=results_year.index.astype('int64')

# %%
results_year
# Out:
#        Jan_Avg  NonJan_Avg    T_Test       P_Value
# Year
# 2013  0.025338    0.020215  0.462210  3.238167e-01
# 2014 -0.048393    0.015644 -6.878267  1.084662e-07
# 2015 -0.036865    0.003989 -3.259459  1.506952e-03
# 2016 -0.048209    0.016798 -4.127663  1.577357e-04
# 2017  0.007511    0.020446 -1.642525  5.603935e-02
# 2018  0.049836   -0.004736  5.578988  3.229549e-06
# 2019  0.056765    0.015470  3.741390  4.368115e-04

# %% [markdown]
# ### 6. b. Use the DataFrame results_year to output the observations where the January effect hypothesis is true with a 95% degree of confidence. What about the observations where the hypothesis is true with 90% degree of confidence.

# %%
results_year[(results_year['T_Test']>0) & (results_year['P_Value']<=.05)]
# Out:
#        Jan_Avg  NonJan_Avg    T_Test   P_Value
# Year
# 2018  0.049836   -0.004736  5.578988  0.000003
# 2019  0.056765    0.015470  3.741390  0.000437

# %%
results_year[(results_year['T_Test']>0) & (results_year['P_Value']<=.10)]
# Out:
#        Jan_Avg  NonJan_Avg    T_Test   P_Value
# Year
# 2018  0.049836   -0.004736  5.578988  0.000003
# 2019  0.056765    0.015470  3.741390  0.000437

# %% [markdown]
# ### 7. Create a bar plot of the average return in January, as well as the average return across all non-January months, for each year in the sample.

# %%
results_year.plot.bar(y=['Jan_Avg', 'NonJan_Avg'], figsize = (16,8) , grid=True);

# %% [markdown]
# ### 8. Briefly explain whether the evidence is consistent with the January effect, and if not, name a couple of limitations of our dataset and/or approach.

# %% [markdown]
# - The evidence is not entirely consistent with the January effect.
# - We see for some years, the average jan return is higher than non-jan return (2018-2019). These three years had signficant p value of 5%
# - None of the stocks showed a January effect WITH a significant p value (.10 or .05), which doesnt support the existence of the effect
# - Limitations: different industries (i.e tech vs retail) may not be cross industry comparable when it comes to the January effect. Certain industries may exhibit this effect more than others. We may need a more diverse sample as well.
# - These calculations also do not take into account events that lead economic downturns/anomalies. For example in times of recession, people don't feel positive about investing which downplays any possible January effect.

# %% [markdown]
# ### The following questions apply to a random sample of fifteen stocks that your group will select by running the following code

# %% [markdown]
# ### Random Stock Selection

# %%
np.random.seed (1000 + 1) 
ticker_list = ['AAPL', 'AXP', 'BA', 'CAT', 'CSCO', 'CVX', 'DIS', 'GS', 'HD', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO',
            'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PFE', 'PG', 'TRV', 'UNH', 'UTX', 'V', 'VZ', 'WMT', 'XOM']
stock_lst = np.random.choice(ticker_list,15,replace=False)
stock_lst
# Out:
# array(['WMT', 'PG', 'GS', 'MMM', 'INTC', 'JNJ', 'TRV', 'NKE', 'PFE', 'BA',
#        'AAPL', 'AXP', 'MSFT', 'MRK', 'UNH'], dtype='<U4')

# %% [markdown]
# ## PART II

# %% [markdown]
# ### 1. Modify the returns_mon DataFrame to store only the monthly return for the fifteen stocks designated for your group.

# %%
returns_mon_mod = returns_mon.copy()

for col in returns_mon_mod.columns:
    ticker = col[4:]
    if ticker not in stock_lst:
        returns_mon_mod.drop(col, axis=1, inplace=True)

# %%
returns_mon_mod.head()
# Out:
#             RET_AAPL   RET_AXP    RET_BA    RET_GS  RET_INTC   RET_JNJ  \
# Date
# 2013-01-31 -0.186780  0.001021 -0.042407  0.116043 -0.016030  0.042560
# 2013-02-28 -0.025611  0.055239  0.046602  0.016160  0.003056  0.037164
# 2013-03-29  0.002850  0.081984  0.110095 -0.017582  0.044952  0.068791
# 2013-04-30  0.000271  0.016945  0.062754 -0.007366  0.092225  0.044382
# 2013-05-31  0.022172  0.101391  0.085096  0.107159  0.023061 -0.004907
#
#              RET_MMM   RET_MRK  RET_MSFT   RET_NKE   RET_PFE    RET_PG  \
# Date
# 2013-01-31  0.059096  0.045167 -0.006174  0.041748  0.060227  0.087951
# 2013-02-28  0.039892 -0.012096  0.020915  0.015316  0.003294  0.013480
# 2013-03-29  0.021969  0.043416  0.028720  0.080240  0.053009  0.011485
# 2013-04-30 -0.015165  0.061423  0.145777  0.074907  0.007251  0.003544
# 2013-05-31  0.057423 -0.006403  0.059941 -0.024281 -0.057086 -0.000131
#
#              RET_TRV   RET_UNH   RET_WMT
# Date
# 2013-01-31  0.074049  0.012210  0.010202
# 2013-02-28  0.024674 -0.032398  0.011795
# 2013-03-29  0.051476  0.071865  0.062074
# 2013-04-30  0.014387  0.046449  0.037893
# 2013-05-31 -0.019985  0.044067 -0.031780

# %% [markdown]
# ### 2. For each stock, compute the cumulative return series over the entire sample (no reset), and store the series in a new DataFrame named sample_ret.

# %%
sample_ret = (1+returns_mon_mod[:]).cumprod()-1

# %%
sample_ret.head()
# Out:
#             RET_AAPL   RET_AXP    RET_BA    RET_GS  RET_INTC   RET_JNJ  \
# Date
# 2013-01-31 -0.186780  0.001021 -0.042407  0.116043 -0.016030  0.042560
# 2013-02-28 -0.207607  0.056316  0.002219  0.134078 -0.013023  0.081305
# 2013-03-29 -0.205348  0.142917  0.112558  0.114139  0.031343  0.155690
# 2013-04-30 -0.205133  0.162284  0.182375  0.105932  0.126459  0.206982
# 2013-05-31 -0.187510  0.280129  0.282991  0.224443  0.152436  0.201059
#
#              RET_MMM   RET_MRK  RET_MSFT   RET_NKE   RET_PFE    RET_PG  \
# Date
# 2013-01-31  0.059096  0.045167 -0.006174  0.041748  0.060227  0.087951
# 2013-02-28  0.101346  0.032524  0.014612  0.057703  0.063719  0.102617
# 2013-03-29  0.125541  0.077353  0.043752  0.142573  0.120105  0.115280
# 2013-04-30  0.108473  0.143527  0.195907  0.228160  0.128227  0.119233
# 2013-05-31  0.172124  0.136204  0.267591  0.198338  0.063821  0.119087
#
#              RET_TRV   RET_UNH   RET_WMT
# Date
# 2013-01-31  0.074049  0.012210  0.010202
# 2013-02-28  0.100550 -0.020583  0.022118
# 2013-03-29  0.157202  0.049803  0.085565
# 2013-04-30  0.173851  0.098565  0.126700
# 2013-05-31  0.150392  0.146975  0.090893

# %% [markdown]
# ### 3a. Which stocks were the top three performers. What were their cumulative returns over the entire sample period?

# %%
sorted_sample=sample_ret.tail(1).iloc[:, np.argsort(sample_ret.loc[sample_ret.index[-1]])]
sorted_sample
# Out:
#               RET_GS   RET_PFE   RET_WMT   RET_MMM   RET_TRV   RET_AXP  \
# Date
# 2019-12-31  0.600979  0.781094  0.843223  0.988239  0.999589  1.023443
#
#               RET_PG   RET_JNJ  RET_MRK  RET_INTC  RET_AAPL   RET_NKE  RET_BA  \
# Date
# 2019-12-31  1.092973  1.326816   1.4919   1.95566  2.300798  2.828238  3.0305
#
#              RET_UNH  RET_MSFT
# Date
# 2019-12-31  4.302828   4.80606

# %%
sorted_sample.iloc[:, [-3,-2,-1]]
# Out:
#             RET_BA   RET_UNH  RET_MSFT
# Date
# 2019-12-31  3.0305  4.302828   4.80606

# %% [markdown]
# ### 3b. Which stocks were the worst three performers. What were their cumulative returns over the entire sample period?

# %%
sorted_sample.iloc[:, [0,1,2]]
# Out:
#               RET_GS   RET_PFE   RET_WMT
# Date
# 2019-12-31  0.600979  0.781094  0.843223

# %% [markdown]
# ### 3c. Create a line plot of the series for the stocks with the highest three and lowest three cumulative returns.

# %%
labels = sorted_sample.iloc[:, [-3,-2,-1]].columns
labels = labels.append(sorted_sample.iloc[:, [0,1,2]].columns)
labels
# Out:
# Index(['RET_BA', 'RET_UNH', 'RET_MSFT', 'RET_GS', 'RET_PFE', 'RET_WMT'], dtype='object')

# %%
fig = plt.figure(figsize=(16,8))
ax = fig.add_subplot(1, 1, 1)

for ticker in labels:
    ax.plot(sample_ret[ticker], label=[ticker])


ax.set_xlim(sample_ret.index[1], sample_ret.index[-1])       

ax.grid(True)

ax.set_title("Highest 3 & Lowest 3")

ax.legend(loc='best');

# %% [markdown]
# ## PART III

# %% [markdown]
# ### 1. Use the DataFrame returns_mon to create a new DataFrame named data_intial that only has the data from January 2013 to December 2017. In addition, create another DataFrame named data_post to store the 2018 and 2019 data.

# %%
data_initial = returns_mon['01/01/2013':'12/31/2017']
data_initial.head()
# Out:
#             RET_AAPL   RET_AXP    RET_BA   RET_CAT  RET_CSCO   RET_CVX  \
# Date
# 2013-01-31 -0.186780  0.001021 -0.042407  0
.0
#
# [5 rows x 29 columns]

# %% [markdown]
# ### 2. Create a DataFrame named rf_rate to store the risk free rate over the period from January 2013 to December 2019. The risk-free rate  is available in the ff_factors19.csv file on Blackboard.

# %%
# reading in data
rf_rate = pd.read_csv("ff_factors19.csv",
                     index_col='dateff',
                     usecols=['dateff', 'rf'],
                     parse_dates=True)

rf_rate = rf_rate["2013/01/01":"2019/12/31"]
rf_rate.tail()
# Out:
#                 rf
# dateff
# 2019-08-30  0.0016
# 2019-09-30  0.0018
# 2019-10-31  0.0015
# 2019-11-29  0.0012
# 2019-12-31  0.0014

# %% [markdown]
# ### 3a. Use the DataFrames data_initial and rf_rate, in conjunction with Scipy' s minimize() function to find the optimal portfolio (highest Sharpe ratio) from the universe of stocks comprised of all the stocks in your sample. (Assume there are no short-selling constraints).

# %%
data_initial.drop(columns=['JAN_DUMMY'], inplace=True)
data_initial.head()
# Out:
# C:\Users\ifteda\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#             RET_AAPL   RET_AXP    RET_BA   RET_CAT  RET_CSCO   RET_CVX  \
# Date
# 2013-01-31 -0.186780  0.001021 -0.042407  0.050977  0.011244  0.042217
# 2013-02-28 -0.025611  0.055239  0.046602 -0.063137  0.014000  0.024975
# 2013-03-29  0.002850  0.081984  0.110095 -0.060239  0.001915  0.014155
# 2013-04-30  0.000271  0.016945  0.062754 -0.020399  0.009008  0.026493
# 2013-05-31  0.022172  0.101391  0.085096  0.013258  0.142336  0.014079
#
#              RET_DIS    RET_GS    RET_HD   RET_IBM  ...   RET_NKE   RET_PFE  \
# Date                                                ...
# 2013-01-31  0.052975  0.116043  0.052773  0.033652  ...  0.041748  0.060227
# 2013-02-28  0.013091  0.016160  0.023336 -0.006892  ...  0.015316  0.003294
# 2013-03-29  0.039686 -0.017582  0.023997  0.060241  ...  0.080240  0.053009
# 2013-04-30  0.101056 -0.007366  0.049895 -0.051762  ...  0.074907  0.007251
# 2013-05-31  0.003812  0.107159  0.069892  0.031373  ... -0.024281 -0.057086
#
#               RET_PG   RET_TRV   RET_UNH   RET_UTX     RET_V    RET_VZ  \
# Date
# 2013-01-31  0.087951  0.074049  0.012210  0.041622  0.016151 -0.003430
# 2013-02-28  0.013480  0.024674 -0.032398  0.039427  0.013066  0.064810
# 2013-03-29  0.011485  0.051476  0.071865  0.031310  0.068219  0.054780
# 2013-04-30  0.003544  0.014387  0.046449 -0.023171 -0.008158  0.102885
# 2013-05-31 -0.000131 -0.019985  0.044067  0.044375  0.063219 -0.106165
#
#              RET_WMT   RET_XOM
# Date
# 2013-01-31  0.010202  0.014104
# 2013-02-28  0.011795  0.001689
# 2013-03-29  0.062074  0.006234
# 2013-04-30  0.037893 -0.012507
# 2013-05-31 -0.031780  0.023388
#
# [5 rows x 28 columns]

# %%
rf_rate_initial = rf_rate[data_initial.index[0] : data_initial.index[-1]]
rf_rate_initial.tail()
# Out:
#                 rf
# dateff
# 2017-08-31  0.0009
# 2017-09-29  0.0009
# 2017-10-31  0.0009
# 2017-11-30  0.0008
# 2017-12-29  0.0009

# %%
# portfolio returns fxn
def port_ret(weights):
    return np.dot(data_initial * 12, weights).mean()

# portfolio standard deviation fxn
def port_std(weights):
    return np.sqrt(np.dot(weights, np.dot(data_initial.cov() * 12, weights)))

# excess portfolio returns fxn
def ex_port_ret(weights):
    return (np.dot(data_initial, weights) - rf_rate_initial['rf']).mean() * 12

# excess portfolio returns standard deviation fxn
def ex_port_std(weights):
    return (np.dot(data_initial, weights) - rf_rate_initial['rf']).std() * np.sqrt(12)

# negative Sharpe Ratio fxn
def neg_SR(weights):
    return -1 * (ex_port_ret(weights) / ex_port_std(weights))

constraints = ({'type': 'eq', 'fun': lambda weights: np.sum(weights) - 1})

boundaries = [(0,1)]
bounds = tuple(boundaries * len(data_initial.columns))

init_guess = np.full(len(data_initial.columns), 1 / len(data_initial.columns))

optimal_port = minimize(neg_SR, 
                        init_guess, 
                        method='SLSQP', 
#                         bounds=bounds, 
                        constraints=constraints)

# %%
optimal_port
# Out:
#      fun: -2.546005685994104
#      jac: array([ 0.79297677,  1.34458643, -0.01737452,  0.33100516,  0.55969235,
#         1.07446119,  1.17557523,  0.99657881, -0.01784548,  1.38000441,
#         0.09543085, -0.01817214,  0.61012447,  0.68288079, -0.01685268,
#         0.06922305,  0.08413425, -0.01841822, -0.01710629,  0.86154696,
#         0.25844187,  0.99047354, -0.01744625,  0.82969365, -0.01682007,
#         0.2580159 ,  0.1899879 ,  0.87018493])
#  message: 'Optimization terminated successfully.'
#     nfev: 338
#      nit: 11
#     njev: 11
#   status: 0
#  success: True
#        x: array([0.00000000e+00, 8.59141621e-16, 6.14727872e-02, 0.00000000e+00,
#        3.99100872e-16, 2.77304284e-16, 5.89166768e-16, 2.86715048e-16,
#        1.00132732e-01, 8.71989478e-17, 1.56026017e-16, 9.15096997e-02,
#        1.75676246e-16, 1.85960991e-16, 1.00058317e-02, 1.64462058e-16,
#        2.08306117e-17, 1.77318877e-01, 4.80679089e-02, 4.55308820e-16,
#        1.06162953e-16, 0.00000000e+00, 3.94434696e-01, 4.48393281e-16,
#        1.17057468e-01, 2.46656297e-17, 1.47534285e-16, 0.00000000e+00])

# %% [markdown]
# ### 3b. The weights of the stocks in the optimal portfolio are:

# %%
for ticker in ticker_list:
    print(ticker + "\t" + str(round(optimal_port.x[ticker_list.index(ticker)], 4)))
# Out:
# AAPL	-0.3954
# AXP	-0.712
# BA	0.7259
# CAT	0.1951
# CSCO	-0.0255
# CVX	0.1492
# DIS	-0.0531
# GS	-0.342
# HD	0.5747
# IBM	-0.1299
# INTC	0.2042
# JNJ	1.0433
# JPM	0.623
# KO	-0.063
# MCD	-0.3578
# MMM	2.0023
# MRK	0.3248
# MSFT	0.4395
# NKE	0.0393
# PFE	-0.6806
# PG	-0.3765
# TRV	-0.771
# UNH	0.7215
# UTX	-0.7042
# V	0.1135
# VZ	-0.1365
# WMT	-0.2779
# XOM	-1.1309

# %% [markdown]
# ### 3c. The optimal portfolio return is:

# %%
port_ret(optimal_port.x)
# Out:
# 0.8972158289450974

# %% [markdown]
# ### 3d. The optimal portfolio standard deviation is:

# %%
port_std(optimal_port.x)
# Out:
# 0.2542801253646461

# %% [markdown]
# ### 3e. The Sharpe Ratio the optimal portfolio is:

# %%
-optimal_port.fun
# Out:
# 3.5225578604721246

# %% [markdown]
# ### 4a. What is the return of the Global Minimum Variance Portfolio (GMVP)

# %%
gmvp_ret = np.dot(12 * data_initial.mean(),
                 np.dot(np.linalg.inv(data_initial.cov() * 12),
                       np.ones(len(data_initial.columns)))) /\
np.dot(np.ones(len(data_initial.columns)),
      np.dot(np.linalg.inv(data_initial.cov() * 12),
            np.ones(len(data_initial.columns))))

gmvp_ret
# Out:
# 0.04656372470903179

# %% [markdown]
# ### 4b. What is the standard deviation of the Global Minimum Variance Portfolio (GMVP)

# %%
gmvp_std = 1 / np.sqrt(np.dot(np.ones(len(data_initial.columns)),
                             np.dot(np.linalg.inv(data_initial.cov() * 12),
                                   np.ones(len(data_initial.columns)))))

gmvp_std
# Out:
# 0.05707915111280503

# %% [markdown]
# ### 4c. What are the weights of the stocks in the Global Minimum Variance Portfolio (GMVP)

# %%
gmvp_weights = np.dot(np.linalg.inv(data_initial.cov() *12),
                     np.ones(len(data_initial.columns))) /\
np.dot(np.ones(len(data_initial.columns)),
      np.dot(np.linalg.inv(data_initial.cov() * 12),
            np.ones(len(data_initial.columns))))

gmvp_weights
# Out:
# array([ 0.11739597,  0.11186816, -0.09212476, -0.07983265,  0.00913805,
#        -0.18520381, -0.21285814,  0.11003658,  0.10544821,  0.07612264,
#         0.02236356,  0.0579219 , -0.11542502, -0.20462004,  0.34428304,
#        -0.6766571 ,  0.08374251, -0.03560956,  0.1944788 , -0.06124345,
#         0.17176676, -0.13145063,  0.13636706,  0.17442973,  0.1921269 ,
#         0.08814137,  0.13171743,  0.66767646])

# %% [markdown]
# ### 5. Use Scipy's minimize() function to solve for the efficient frontier. In addition, plot it, add to the plot the fifteen stocks, the GMVP, the optimal portfolio, as well as the Capital Allocation Line.

# %%
frontier_y = np.arange(gmvp_ret, port_ret(optimal_port.x)*1.5,0.01)
frontier_y
# Out:
# array([0.04656372, 0.05656372, 0.06656372, 0.07656372, 0.08656372,
#        0.09656372, 0.10656372, 0.11656372, 0.12656372, 0.13656372,
#        0.14656372, 0.15656372, 0.16656372, 0.17656372, 0.18656372,
#        0.19656372, 0.20656372, 0.21656372, 0.22656372, 0.23656372,
#        0.24656372, 0.25656372, 0.26656372, 0.27656372, 0.28656372,
#        0.29656372, 0.30656372, 0.31656372, 0.32656372, 0.33656372,
#        0.34656372, 0.35656372, 0.36656372, 0.37656372])

# %%
frontier_x = []

for ret in frontier_y:
    constraints = ({'type': 'eq', 'fun': lambda weights: np.sum(weights) - 1},
                  {'type': 'eq', 'fun': lambda weights: port_ret(weights) - ret})
    
    init_guess = np.full(len(data_initial.columns), 1 / len(data_initial.columns))
    
    boundaries = [(0,1)]
    bounds = tuple(boundaries * len(data_initial.columns))
    
    result = minimize(port_std, 
                      init_guess, 
                      method='SLSQP', 
#                       bounds=bounds, 
                      constraints=constraints)
    
    frontier_x.append(result.fun)
    
frontier_x = np.array(frontier_x)
# Out:
# 0.04656372470903179 	 0.08832931246166285
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-3fc4af69122e> in <module>
#      14                       method='SLSQP',
#      15                       bounds=bounds,
# ---> 16                       constraints=constraints)
#      17     print(ret, "\t", result.fun)
#      18
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     607     elif meth == 'slsqp':
#     608         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 609                                constraints, callback=callback, **options)
#     610     elif meth == 'trust-constr':
#     611         return _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     421             # Compute the derivatives of the objective function
#     422             # For some reason SLSQP wants g dimensioned to n+1
# --> 423             g = append(fprime(x), 0.0)
#     424
#     425             # Compute the normals of the constraints
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\slsqp.py in approx_jacobian(x, func, epsilon, *args)
#      61     for i in range(len(x0)):
#      62         dx[i] = epsilon
# ---> 63         jac[i] = (func(*((x0+dx,)+args)) - f0)/epsilon
#      64         dx[i] = 0.0
#      65
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# <ipython-input-80-bfa07fa566e7> in port_std(weights)
#       5 # portfolio standard deviation fxn
#       6 def port_std(weights):
# ----> 7     return np.sqrt(np.dot(weights, np.dot(data_initial.cov() * 12, weights)))
#       8
#       9 # excess portfolio returns fxn
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in f(self, other, axis, level, fill_value)
#    2034
#    2035             assert np.ndim(other) == 0
# -> 2036             return self._combine_const(other, op)
#    2037
#    2038     f.__name__ = op_name
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _combine_const(self, other, func)
#    5118     def _combine_const(self, other, func):
#    5119         assert lib.is_scalar(other) or np.ndim(other) == 0
# -> 5120         return ops.dispatch_to_series(self, other, func)
#    5121
#    5122     def combine(self, other, func, fill_value=None, overwrite=True):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in dispatch_to_series(left, right, func, str_rep, axis)
#    1155         raise NotImplementedError(right)
#    1156
# -> 1157     new_data = expressions.evaluate(column_op, str_rep, left, right)
#    1158
#    1159     result = left._constructor(new_data, index=left.index, copy=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     206     use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#     210
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     121
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#     125     return result
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      66         _store_test_result(False)
#      67     with np.errstate(all='ignore'):
# ---> 68         return op(a, b)
#      69
#      70
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in column_op(a, b)
#    1126         def column_op(a, b):
#    1127             return {i: func(a.iloc[:, i], b)
# -> 1128                     for i in range(len(a.columns))}
#    1129
#    1130     elif isinstance(right, ABCDataFrame):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in <dictcomp>(.0)
#    1126         def column_op(a, b):
#    1127             return {i: func(a.iloc[:, i], b)
# -> 1128                     for i in range(len(a.columns))}
#    1129
#    1130     elif isinstance(right, ABCDataFrame):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#    1583         result = safe_na_op(lvalues, rvalues)
#    1584         return construct_result(left, result,
# -> 1585                                 index=left.index, name=res_name, dtype=None)
#    1586
#    1587     wrapper.__name__ = op_name
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in _construct_result(left, result, index, name, dtype)
#    1472     not be enough; we still need to override the name attribute.
#    1473     """
# -> 1474     out = left._constructor(result, index=index, dtype=dtype)
#    1475
#    1476     out.name = name
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _constructor(self)
#     336     # ----------------------------------------------------------------------
#     337
# --> 338     @property
#     339     def _constructor(self):
#     340         return Series
#
# KeyboardInterrupt:

# %%
frontier_x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-3e67fd85a24a> in <module>
# ----> 1 frontier_x
#
# NameError: name 'frontier_x' is not defined

# %%
frontier_y
# Out:
# array([0.04669605, 0.05669605, 0.06669605, 0.07669605, 0.08669605,
#        0.09669605, 0.10669605, 0.11669605, 0.12669605, 0.13669605,
#        0.14669605, 0.15669605, 0.16669605, 0.17669605, 0.18669605,
#        0.19669605, 0.20669605, 0.21669605, 0.22669605, 0.23669605,
#        0.24669605, 0.25669605, 0.26669605, 0.27669605, 0.28669605,
#        0.29669605, 0.30669605, 0.31669605, 0.32669605, 0.33669605,
#        0.34669605, 0.35669605, 0.36669605, 0.37669605, 0.38669605,
#        0.39669605, 0.40669605, 0.41669605, 0.42669605, 0.43669605,
#        0.44669605, 0.45669605, 0.46669605, 0.47669605, 0.48669605,
#        0.49669605, 0.50669605, 0.51669605, 0.52669605, 0.53669605,
#        0.54669605, 0.55669605, 0.56669605, 0.57669605, 0.58669605,
#        0.59669605, 0.60669605, 0.61669605, 0.62669605, 0.63669605,
#        0.64669605, 0.65669605, 0.66669605, 0.67669605, 0.68669605,
#        0.69669605, 0.70669605, 0.71669605, 0.72669605, 0.73669605,
#        0.74669605, 0.75669605, 0.76669605, 0.77669605, 0.78669605,
#        0.79669605, 0.80669605, 0.81669605, 0.82669605, 0.83669605,
#        0.84669605, 0.85669605, 0.86669605, 0.87669605, 0.88669605,
#        0.89669605, 0.90669605, 0.91669605, 0.92669605, 0.93669605,
#        0.94669605, 0.95669605, 0.96669605, 0.97669605, 0.98669605,
#        0.99669605, 1.00669605, 1.01669605, 1.02669605, 1.03669605,
#        1.04669605, 1.05669605, 1.06669605, 1.07669605, 1.08669605,
#        1.09669605, 1.10669605, 1.11669605, 1.12669605, 1.13669605,
#        1.14669605, 1.15669605, 1.16669605, 1.17669605, 1.18669605,
#        1.19669605, 1.20669605, 1.21669605, 1.22669605, 1.23669605,
#        1.24669605, 1.25669605, 1.26669605, 1.27669605, 1.28669605,
#        1.29669605, 1.30669605, 1.31669605, 1.32669605, 1.33669605])

# %%
# create 16" x 10" figure
fig = plt.figure(figsize = (16,10))

# add subplot
ax = fig.add_subplot()

# # plot data and add colorbar
# ax.scatter(port_std_arr, port_ret_arr, c=SR_arr)
# fig.colorbar(ax.scatter(port_std_arr, port_ret_arr, c=SR_arr),
#             ax=ax, label='Sharpe Ratio')

# add limits to axes
ax.set_xlim(gmvp_std * 0.5, port_std(optimal_port.x) * 2)
ax.set_ylim(-0.5 * port_ret(optimal_port.x), port_ret(optimal_port.x) * 2)

# add green dot for Optimal Risky Portfolio
ax.scatter(port_std(optimal_port.x), port_ret(optimal_port.x), color='green', s=100)
ax.annotate('OP', (port_std(optimal_port.x), port_ret(optimal_port.x)))

# add blue dot for Global Minimum Variance Portfolio
ax.scatter(gmvp_std, gmvp_ret, color='blue', s=100)
ax.annotate('GMVP', (gmvp_std, gmvp_ret))

# draw Capital Allocation Line (CAL)
ax.plot(np.arange(0, frontier_x[-1], 0.01),
       (rf_rate_initial['rf'].mean() * 12) + (-optimal_port.fun) * np.arange(0.0, frontier_x[-1], 0.01),
       color='green', label='Capital Allocation Line')

# annotate stocks
for ticker in ticker_list:
    ax.scatter(data_initial['RET_'+ticker].std() * np.sqrt(12),
              data_initial['RET_'+ticker].mean(), color='red', s=100)
    ax.annotate(ticker, (data_initial['RET_'+ticker].std() * np.sqrt(12),
              data_initial['RET_'+ticker].mean()))

# draw frontier line
plt.plot(frontier_x, frontier_y, color="blue", linestyle='--', linewidth=3)

# add title to plot
ax.set_title('Portfolio Optimization')

# add axis labels
ax.set_xlabel('Portfolio Standard Deviation')
ax.set_ylabel('Portfolio Return')

# add legend to graph
ax.legend(loc='best')

# %% [markdown]
# ## PART IV

# %% [markdown]
# ### 1. Create a DataFrame named weights with three columns: 1) TICKER; 2) Optimal_Weights and 3) Equal_Weights for each ticker.

# %%
data_post.drop(columns=['JAN_DUMMY'], inplace=True)
data_post.head()
# Out:
#             RET_AAPL   RET_AXP    RET_BA   RET_CAT  RET_CSCO   RET_CVX  \
# Date
# 2018-01-31 -0.010693  0.004428  0.183671  0.037097  0.088638  0.001277
# 2018-02-28  0.065961 -0.019197  0.026807 -0.051364  0.075105 -0.103420
# 2018-03-30 -0.059804 -0.044349 -0.099576 -0.048021 -0.043123  0.018765
# 2018-04-30 -0.015134  0.060733  0.017175 -0.015682  0.040127  0.092644
# 2018-05-31  0.126742 -0.004567  0.059239  0.050978 -0.036326  0.002187
#
#              RET_DIS    RET_GS    RET_HD   RET_IBM  ...   RET_NKE   RET_PFE  \
# Date                                                ...
# 2018-01-31  0.010732  0.050255  0.058260  0.064856  ...  0.086772  0.022387
# 2018-02-28 -0.052035 -0.015886 -0.097318 -0.039472  ... -0.017598 -0.010684
# 2018-03-30 -0.026721 -0.043014 -0.016671 -0.015521  ... -0.005821 -0.022842
# 2018-04-30 -0.001096 -0.055217  0.036143 -0.056787  ...  0.028927  0.031070
# 2018-05-31 -0.008609 -0.050122  0.015008 -0.014462  ...  0.048658 -0.009034
#
#               RET_PG   RET_TRV   RET_UNH   RET_UTX     RET_V    RET_VZ  \
# Date
# 2018-01-31 -0.054600  0.100097  0.071415  0.078661  0.085761  0.032635
# 2018-02-28 -0.094940 -0.075628 -0.045889 -0.018439 -0.008699 -0.124510
# 2018-03-30  0.009633  0.004190 -0.051961 -0.068495 -0.027376  0.001674
# 2018-04-30 -0.082395 -0.053699  0.099549 -0.046111  0.058921  0.043998
# 2018-05-31  0.011408 -0.023682  0.021386  0.043757  0.031422 -0.034636
#
#              RET_WMT   RET_XOM
# Date
# 2018-01-31  0.076492  0.042829
# 2018-02-28 -0.169163 -0.131870
# 2018-03-30 -0.005677 -0.015032
# 2018-04-30 -0.005749  0.041224
# 2018-05-31 -0.062987  0.053994
#
# [5 rows x 28 columns]

# %%
# creating df
weights_tup = []

equal_weight = 1 / len(data_post.columns)

for ticker in ticker_list:
    weights_tup.append((ticker, optimal_port.x[ticker_list.index(ticker)], equal_weight))

weights = pd.DataFrame(weights_tup, columns=["TICKER", "Optimal_Weights", "Equal_Weights"])
weights.set_index('TICKER', inplace=True)
weights
# Out:
#         Optimal_Weights  Equal_Weights
# TICKER
# AAPL          -0.395421       0.035714
# AXP           -0.712040       0.035714
# BA             0.725861       0.035714
# CAT            0.195088       0.035714
# CSCO          -0.025456       0.035714
# CVX            0.149216       0.035714
# DIS           -0.053056       0.035714
# GS            -0.342048       0.035714
# HD             0.574667       0.035714
# IBM           -0.129905       0.035714
# INTC           0.204171       0.035714
# JNJ            1.043316       0.035714
# JPM            0.622996       0.035714
# KO            -0.062957       0.035714
# MCD           -0.357766       0.035714
# MMM            2.002294       0.035714
# MRK            0.324759       0.035714
# MSFT           0.439513       0.035714
# NKE            0.039296       0.035714
# PFE           -0.680569       0.035714
# PG            -0.376530       0.035714
# TRV           -0.771001       0.035714
# UNH            0.721497       0.035714
# UTX           -0.704237       0.035714
# V              0.113526       0.035714
# VZ            -0.136467       0.035714
# WMT           -0.277884       0.035714
# XOM           -1.130863       0.035714

# %% [markdown]
# ### 2. Using the DataFrames data_post and weights, compute the two portfolio (Optimal and Equal-weighted) monthy returns over the period January 1st, 2018 and December 31st, 2019. Store the portfolio returns into a new DataFrame named port_returns. Label the two columns as 'Optimal Portfolio' and 'EW_Portfolio'

# %%
rf_rate_post = rf_rate[data_post.index[0] : data_post.index[-1]]
rf_rate_post.head()
# Out:
#                 rf
# dateff
# 2018-01-31  0.0011
# 2018-02-28  0.0011
# 2018-03-29  0.0012
# 2018-04-30  0.0014
# 2018-05-31  0.0014

# %%
# for ticker in weights.index:
#     print(weights.loc[ticker]['Optimal_Weights'])
#     print(weights.loc[ticker]['Equal_Weights'])
#     print()

# port_ret(weights['Optimal_Weights'])
port_ret(weights.loc[ticker]['Optimal_Weights'])
# Out:
# -0.1690397826602386

# %%
weights.head()
# Out:
# 130

# %% [markdown]
# ### 3. In a single output, provide summary statistics on the two portfolios.

# %%
# one function

# %% [markdown]
# ### 4a. Compute the two-year cumulative return series for both portfolios and plot them in the same graph.

# %% [markdown]
# ### 4b. What was the two-year cumulative return for the best performer? What was the two-year cumulative return for the worst performer?
